# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical


# Load dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to range [0, 1]
x_train = x_train / 255.0
x_test = x_test / 255.0

# Reshape data to flatten images (28x28 -> 784)
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# One-hot encode labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)


# Create model
model = Sequential([
    Flatten(input_shape=(28, 28, 1)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Display model summary
model.summary()


# Train model
history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)


# Evaluate model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')

# Plot training history
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()


# Make predictions
predictions = model.predict(x_test)

# Visualize sample predictions
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i].reshape(28, 28), cmap=plt.cm.binary)
    plt.xlabel(np.argmax(predictions[i]))
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_4 (Dense)             (None, 128)               100480
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.2810 - accuracy: 0.9194 - val_loss: 0.1693 - val_accuracy: 0.9500
# Epoch 2/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1245 - accuracy: 0.9637 - val_loss: 0.1188 - val_accuracy: 0.9660
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0854 - accuracy: 0.9746 - val_loss: 0.1012 - val_accuracy: 0.9691
# Epoch 4/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0628 - accuracy: 0.9807 - val_loss: 0.0923 - val_accuracy: 0.9726
# Epoch 5/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0482 - accuracy: 0.9858 - val_loss: 0.0852 - val_accuracy: 0.9743
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0394 - accuracy: 0.9880 - val_loss: 0.1041 - val_accuracy: 0.9712
# Epoch 7/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0301 - accuracy: 0.9911 - val_loss: 0.0889 - val_accuracy: 0.9745
# Epoch 8/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0230 - accuracy: 0.9932 - val_loss: 0.0878 - val_accuracy: 0.9772
# Epoch 9/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0190 - accuracy: 0.9945 - val_loss: 0.1049 - val_accuracy: 0.9718
# Epoch 10/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0169 - accuracy: 0.9949 - val_loss: 0.0964 - val_accuracy: 0.9763
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0863 - accuracy: 0.9767
# Test accuracy: 0.9767000079154968
# 313/313 [==============================] - 1s 2ms/step
